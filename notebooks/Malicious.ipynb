# %%
import importlib
import types
from eth2spec.config.config_util import prepare_config
from eth2spec.utils.ssz.ssz_impl import hash_tree_root

import os, sys
# Load current beacon runner specs (v1.1.0-alpha.3)
sys.path.insert(1, os.path.realpath(os.path.pardir))

import beaconrunner as br

prepare_config(".", "fast.yaml")

br.reload_package(br)

# %%
def extract_state(s):
    validators = s["network"].validators
    validator = validators[1]
    head = br.specs.get_head(validator.store)
    current_state = validator.store.block_states[head].copy()
    return current_state

def current_slot(params, step, sL, s, _input):
    return ("current_slot", s["network"].validators[0].data.slot)

def total_balance_asap(params, step, sL, s, _input):
    validators = s["network"].validators
    current_state = extract_state(s)
    current_epoch = br.specs.get_current_epoch(current_state)
    asap_indices = [i for i, v in enumerate(validators) if v.validator_behaviour == "asap"]
    asap_balances = [b for i, b in enumerate(current_state.balances) if i in asap_indices]
    return ("total_balance_asap", sum(asap_balances))

def total_balance_malicious(params, step, sL, s, _input):
    validators = s["network"].validators
    current_state = extract_state(s)
    current_epoch = br.specs.get_current_epoch(current_state)
    malicious_indices = [i for i, v in enumerate(validators) if v.validator_behaviour == "malicious"]
    malicious_balances = [b for i, b in enumerate(current_state.balances) if i in malicious_indices]
    return ("total_balance_malicious", sum(malicious_balances))

def get_base_reward(params, step, sL, s, _input):
    current_state = extract_state(s)
    base_reward = br.specs.get_base_reward(current_state, 0)
    return ("base_reward", base_reward)

def get_block_proposer(params, step, sL, s, _input):
    current_state = extract_state(s)
    block_proposer = [v.validator_index for v in s["network"].validators if v.data.current_proposer_duties[s["current_slot"] % br.specs.SLOTS_PER_EPOCH]][0]
    return ("block_proposer", block_proposer)

def get_block_proposer_balance(params, step, sL, s, _input):
    current_state = extract_state(s)
    block_proposer_balance = current_state.balances[s["block_proposer"]]
    return ("block_proposer_balance", block_proposer_balance)

def get_sync_committee(params, step, sL, s, _input):
    current_state = extract_state(s)
    current_epoch = br.specs.get_current_epoch(current_state)
    sync_committee = current_state.current_sync_committee
    sync_committee = br.specs.get_sync_committee_indices(current_state, current_epoch)
    return ("sync_committee", sync_committee)

def get_head(params, step, sL, s, _input):
    validators = s["network"].validators
    validator = validators[0]
    head = br.specs.get_head(validator.store).hex()[0:6]
    return ("head", head)

def get_malicious_head(params, step, sL, s, _input):
    malicious_head = s['malicious_data'].malicious_head
    return ('malicious_head', malicious_head)

def get_current_validator_state(params, step, sL, s, _input):
    current_state = extract_state(s)
    current_validator_state = []
    for v in s["network"].validators:
        current_validator_state += [{
            "slot": v.data.slot,
            "validator_index": v.validator_index,
            "balance": current_state.balances[v.validator_index],
            "block_proposer": 1 if s["block_proposer"] == v.validator_index else 0,
            "attester": 1 if v.data.current_attest_slot == v.data.slot else 0,
            "sync_committee": len(v.data.current_sync_committee),
        }]
    return ("current_validator_state", current_validator_state)

observers = {
    "current_slot": current_slot,
    "total_balance_asap": total_balance_asap,
    "total_balance_malicious": total_balance_malicious,
    "base_reward": get_base_reward,
    "block_proposer": get_block_proposer,
    "block_proposer_balance": get_block_proposer_balance,
#     "sync_committee": get_sync_committee,
    "head": get_head,
    "malicious_head": get_malicious_head,
    "current_validator_state": get_current_validator_state,
}

# %%
from random import sample
from beaconrunner.validators.ASAPValidator import ASAPValidator
from beaconrunner.validators.MaliciousValidator import MaliciousValidator

def simulate_once(network_sets, num_run, num_validators, network_update_rate):
    
    num_malicious = int((3 * num_validators) / 10)

    # We sample the position on the p2p network of prudent validators randomly
    maliciousset = set(sample(range(num_validators), num_malicious))

    validators = []
    malicious_validators = []

    # Initiate validators
    for i in range(num_validators):
        if i in maliciousset:
            new_validator = MaliciousValidator(i)
            malicious_validators.append(new_validator)
        else:
            new_validator = ASAPValidator(i)
        validators.append(new_validator)
    
    # Create a genesis state
    # Create a genesis state
    (genesis_state, genesis_block) = br.simulator.get_genesis_state_block(validators)

# Validators load the state
    [v.load_state(genesis_state.copy(), genesis_block.copy()) for v in validators]

    
#     # Validators load the state
#     [v.load_state(genesis_state.copy(),genesis_block.copy()) for v in validators]

    network = br.network.Network(validators = validators, sets=network_sets)
    malicious_data = br.validatorlib.MaliciousData()
    malicious_data.malicious_validators = malicious_validators
    
    malicious_validator_indices = []
    
    for i in malicious_validators:
        malicious_validator_indices.append(i.validator_index)
        
    malicious_data.malicious_validator_indices = malicious_validator_indices

    parameters = br.simulator.SimulationParameters({
        "num_epochs": 20,
        "num_run": num_run,
        "run_index": 1,
        "frequency": 1,
        "network_update_rate": network_update_rate,
    })

    return br.simulator.simulate(network, malicious_data, parameters, observers)

# %%
# %%capture

import pandas as pd

num_validators = 12

# Create the network peers
set_a = br.network.NetworkSet(validators=list(range(num_validators)))
network_sets = list([set_a])

num_runs = 1
network_update_rate = 0.25

#df = pd.concat([simulate_once(network_sets, num_run, num_validators, network_update_rate) for num_run in range(num_runs)])
df = simulate_once(network_sets,num_runs,num_validators,network_update_rate)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-030ec40d34fb> in <module>
#      11
#      12 #df = pd.concat([simulate_once(network_sets, num_run, num_validators, network_update_rate) for num_run in range(num_runs)])
# ---> 13 df = simulate_once(network_sets,num_runs,num_validators,network_update_rate)
#
# <ipython-input-7-161744cc3eea> in simulate_once(network_sets, num_run, num_validators, network_update_rate)
#      52     })
#      53
# ---> 54     return br.simulator.simulate(network, malicious_data, parameters, observers)
#
# ~\Documents\GitHub\beaconrunner\beaconrunner\simulator.py in simulate(network, malicious_data, parameters, observers)
#     357     exec_context = ExecutionContext()
#     358     simulation = Executor(exec_context=exec_context, configs=configs)
# --> 359     raw_result, tensor, sessions = simulation.execute()
#     360
#     361     return pd.DataFrame(raw_result)
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\__init__.py in execute(self)
#     154
#     155             print("Execution Method: " + self.exec_method.__name__)
# --> 156             simulations_results = self.exec_method(
#     157                 sim_executors, var_dict_list, states_lists, configs_structs, env_processes_list, Ts, SimIDs, RunIDs,
#     158                 ExpIDs, SubsetIDs, SubsetWindows, original_N
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\execution.py in local_simulations(simulation_execs, var_dict_list, states_lists, configs_structs, env_processes_list, Ts, SimIDs, Ns, ExpIDs, SubsetIDs, SubsetWindows, configured_n)
#     134         if config_amt == 1: # and configured_n != 1
#     135             _params = var_dict_list[0]
# --> 136             return single_proc_exec(
#     137                 simulation_execs, _params, states_lists, configs_structs, env_processes_list,
#     138                 Ts, SimIDs, Ns, ExpIDs, SubsetIDs, SubsetWindows, configured_n
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\execution.py in single_proc_exec(simulation_execs, var_dict_list, states_lists, configs_structs, env_processes_list, Ts, SimIDs, Ns, ExpIDs, SubsetIDs, SubsetWindows, configured_n)
#      35         map(lambda x: x.pop(), params)
#      36     )
# ---> 37     result = simulation_exec(
#      38         var_dict_list, states_list, config, env_processes, T, sim_id, N, subset_id, subset_window, configured_n
#      39     )
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in simulation(self, sweep_dict, states_list, configs, env_processes, time_seq, simulation_id, run, subset_id, subset_window, configured_N, additional_objs)
#     247
#     248         pipe_run = flatten(
# --> 249             [execute_run(sweep_dict, states_list, configs, env_processes, time_seq, run)]
#     250         )
#     251
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in execute_run(sweep_dict, states_list, configs, env_processes, time_seq, _run)
#     239             )
#     240
# --> 241             first_timestep_per_run: List[Dict[str, Any]] = self.run_pipeline(
#     242                 sweep_dict, states_list_copy, configs, env_processes, time_seq, run, additional_objs
#     243             )
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in run_pipeline(self, sweep_dict, states_list, configs, env_processes, time_seq, run, additional_objs)
#     196
#     197         for time_step in time_seq:
# --> 198             pipe_run: List[Dict[str, Any]] = self.state_update_pipeline(
#     199                 sweep_dict, simulation_list, configs, env_processes, time_step, run, additional_objs
#     200             )
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in state_update_pipeline(self, sweep_dict, simulation_list, configs, env_processes, time_step, run, additional_objs)
#     171         sub_step += 1
#     172         for [s_conf, p_conf] in configs:
# --> 173             states_list: List[Dict[str, Any]] = self.partial_state_update(
#     174                 sweep_dict, sub_step, states_list, simulation_list, s_conf, p_conf, env_processes, time_step, run,
#     175                 additional_objs
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in partial_state_update(self, sweep_dict, sub_step, sL, sH, state_funcs, policy_funcs, env_processes, time_step, run, additional_objs)
#     117         last_in_obj: Dict[str, Any] = sL[-1].copy()
#     118         _input: Dict[str, Any] = self.policy_update_exception(
# --> 119             self.get_policy_input(sweep_dict, sub_step, sH, last_in_obj, policy_funcs, additional_objs)
#     120         )
#     121
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in get_policy_input(self, sweep_dict, sub_step, sL, s, funcs, additional_objs)
#      52             return result
#      53
# ---> 54         col_results = get_col_results(sweep_dict, sub_step, sL, s, funcs)
#      55         key_set = list(set(list(reduce(lambda a, b: a + b, list(map(lambda x: list(x.keys()), col_results))))))
#      56         new_dict = {k: [] for k in key_set}
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in get_col_results(sweep_dict, sub_step, sL, s, funcs)
#      39                 else:
#      40                     return f(sweep_dict, sub_step, sL, s, additional_objs)
# ---> 41             return list(map(lambda f: policy_scope_tuner(additional_objs, f), funcs))
#      42
#      43         def compose(init_reduction_funct, funct_list, val_list):
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in <lambda>(f)
#      39                 else:
#      40                     return f(sweep_dict, sub_step, sL, s, additional_objs)
# ---> 41             return list(map(lambda f: policy_scope_tuner(additional_objs, f), funcs))
#      42
#      43         def compose(init_reduction_funct, funct_list, val_list):
#
# c:\users\shyam\documents\github\beaconrunner\env\lib\site-packages\cadCAD\engine\simulation.py in policy_scope_tuner(additional_objs, f)
#      36             def policy_scope_tuner(additional_objs, f):
#      37                 if additional_objs is None:
# ---> 38                     return f(sweep_dict, sub_step, sL, s)
#      39                 else:
#      40                     return f(sweep_dict, sub_step, sL, s, additional_objs)
#
# ~\Documents\GitHub\beaconrunner\beaconrunner\simulator.py in propose_policy(params, step, sL, s)
#     222
#     223         known_items = knowledge_set(network, validator_index)
# --> 224         block = validator.propose(known_items)
#     225         if block is not None:
#     226             produced_blocks.append(block)
#
# ~\Documents\GitHub\beaconrunner\beaconrunner\validators\ASAPValidator.py in propose(self, known_items)
#     110
#     111         # honest propose
# --> 112         return honest_propose(self, known_items)
#
# ~\Documents\GitHub\beaconrunner\beaconrunner\validatorlib.py in honest_propose(validator, known_items)
#    1025         process_sync_committee_contributions(beacon_block, sc_contributions)
#    1026
# -> 1027     process_block(processed_state, beacon_block)
#    1028     state_root = hash_tree_root(processed_state)
#    1029     beacon_block.state_root = state_root
#
# ~\Documents\GitHub\beaconrunner\beaconrunner\specs.py in process_block(state, block)
#    1312
#    1313 def process_block(state: BeaconState, block: BeaconBlock) -> None:
# -> 1314     process_block_header(state, block)
#    1315     process_randao(state, block.body)
#    1316     process_eth1_data(state, block.body)
#
# ~\Documents\GitHub\beaconrunner\beaconrunner\specs.py in process_block_header(state, block)
#    1323     assert block.slot == state.slot
#    1324     # Verify that the block is newer than latest block header
# -> 1325     assert block.slot > state.latest_block_header.slot
#    1326     # Verify that proposer index is the correct index
#    1327     assert block.proposer_index == get_beacon_proposer_index(state)
#
# AssertionError:
